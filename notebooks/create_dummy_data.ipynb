# %%
import pandas as pd

# %%
df = pd.read_csv('test_data')

# %%
df.head()
# Out:
#    sleep_duration  heart_rate    bmi  calorie_expenditure  step_count  \
# 0            7.65        75.2  22.98               1881.0      6995.0
# 1            8.95        74.4  18.57               1940.0     10242.0
# 2            6.86        90.9  23.17               2036.0      5786.0
# 3            6.80        61.2  18.43               2247.0     12669.0
# 4            8.27        74.7  22.36               2722.0     13482.0
#
#    exercise_duration  water_intake diet_type stress_level sleep_quality  \
# 0               50.4          2.33       veg       medium          poor
# 1               32.5          2.29       veg          low       average
# 2               27.2          2.50  balanced         high          poor
# 3               55.3          2.65  balanced       medium          good
# 4               58.0          3.17       veg         high       average
#
#   physical_activity_level smoking_alcohol gender health_condition
# ...

# %%
dummy_data = df.loc[0:3]

# %%
dummy_data.head()
# Out:
#    sleep_duration  heart_rate    bmi  calorie_expenditure  step_count  \
# 0            7.65        75.2  22.98               1881.0      6995.0
# 1            8.95        74.4  18.57               1940.0     10242.0
# 2            6.86        90.9  23.17               2036.0      5786.0
# 3            6.80        61.2  18.43               2247.0     12669.0
#
#    exercise_duration  water_intake diet_type stress_level sleep_quality  \
# 0               50.4          2.33       veg       medium          poor
# 1               32.5          2.29       veg          low       average
# 2               27.2          2.50  balanced         high          poor
# 3               55.3          2.65  balanced       medium          good
#
#   physical_activity_level smoking_alcohol gender health_condition
# 0                  active      occasional   male          at-risk
# 1                  active      occasional   male              fit
# ...

# %%
dummy_data.to_csv("script_data", index=False)
